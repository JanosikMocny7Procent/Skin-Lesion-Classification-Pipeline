# %%
import os

srcPath="ISIC2"
for folder in os.listdir(srcPath):
    if os.path.isdir(os.path.join(srcPath, folder)):
        print(f"Length of {folder} folder is {len(os.listdir(os.path.join(srcPath, folder)))}")
# Out:
# Length of DF folder is 239
# Length of MEL folder is 4522
# Length of NV folder is 12875
# Length of SCC folder is 628
# Length of BCC folder is 3323
# Length of VASC folder is 253
# Length of BKL folder is 2624
# Length of AK folder is 867
